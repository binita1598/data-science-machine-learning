# %%
import  pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#1, df=pd.read_excel("Salary.xlsx")

# %%
df.head()
# Out:
#    Age      Workclass  Fnlwgt    Education  Experience Marital Status  \
# 0   23        Private  205865    Bachelors           1      Unmarried
# 1   33  Self Employed  155781  High School          10        Married
# 2   54  Self Employed  406468    Bachelors          13        Married
# 3   48        Private  144397    Bachelors          10       Divorced
# 4   35  Self Employed  372525    Bachelors          12       Unarried
#
#            Occupation     Sex  Hours per Week    Salary
# 0   Executive Manager    Male              28  31577.01
# 1           Craftsman    Male              60  34000.00
# 2               Sales    Male              40  37890.69
# 3  Technical  Support  Female              30  25541.66
# 4   Executive Manager    Male              40  28454.01

# %%
df[
    (df['Age']>=23) &
    (df['Age']<51)
    ]
# Out:
#      Age      Workclass  Fnlwgt    Education  Experience Marital Status  \
# 0     23        Private  205865    Bachelors           1      Unmarried
# 1     33  Self Employed  155781  High School          10        Married
# 3     48        Private  144397    Bachelors          10       Divorced
# 4     35  Self Employed  372525    Bachelors          12       Unarried
# 5     28        Private  164170       Others           4        Married
# ..   ...            ...     ...          ...         ...            ...
# 321   46  Self Employed  198759      Masters          15        Married
# 322   39        Private  143123      Masters          11        Married
# 323   39        Private  237713    Bachelors          15        Married
# 325   50  Self Employed  167793      Masters          15        Married
# 326   46        Private  456062    Doctorate          16        Married
#
#                   Occupation     Sex  Hours per Week    Salary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327 entries, 23 to 46
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Workclass       327 non-null    object
#  1   Fnlwgt          327 non-null    int64
#  2   Education       327 non-null    object
#  3   Experience      327 non-null    int64
#  4   Marital Status  327 non-null    object
#  5   Occupation      327 non-null    object
#  6   Sex             327 non-null    object
#  7   Hours per Week  327 non-null    int64
#  8   Salary          327 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 35.5+ KB

# %%
df.describe()
# Out:
#               Fnlwgt  Experience  Hours per Week         Salary
# count     327.000000  327.000000      327.000000     327.000000
# mean   192857.749235    9.146789       42.770642   63588.046985
# std    104549.017846    5.012547       14.755658   70503.546357
# min     21906.000000    0.000000        5.000000     727.964193
# 25%    122206.000000    6.000000       40.000000   27384.850000
# 50%    175878.000000    9.000000       40.000000   42430.840000
# 75%    240945.000000   13.000000       50.000000   74003.340000
# max    595000.000000   29.000000       99.000000  600445.610000

# %%
df.describe(include=object)
# Out:
#        Workclass  Education Marital Status Occupation   Sex
# count        327        327            327        327   327
# unique         4         10              7         22     2
# top      Private  Bachelors        Married     Others  Male
# freq         238        139            170         44   235

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Experience',
#        'Marital Status', 'Occupation', 'Sex', 'Hours per Week', 'Salary'],
#       dtype='object')

# %%
df.shape
# Out:
# (327, 10)

# %%
#3 null values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Experience        0
# Marital Status    0
# Occupation        0
# Sex               0
# Hours per Week    0
# Salary            0
# dtype: int64

# %%
df['Marital Status'].value_counts()
# Out:
# Married          170
# Unmarried         81
# Divorced          59
# Widowed           12
# Separated          3
# Never-married      1
# Unarried           1
# Name: Marital Status, dtype: int64

# %%
max_salary=df['Salary'].max()
max_salary
# Out:
# 600445.61

# %%
df[df['Salary']==df['Salary'].max()]
# Out:
#      Age Workclass  Fnlwgt  Education  Experience Marital Status  \
# 111   42   Private  118494  Doctorate          10        Married
#
#             Occupation   Sex  Hours per Week     Salary
# 111  Backend Developer  Male              44  600445.61

# %%
#4.max salary with marital status
df.groupby("Marital Status", sort=False)["Salary"].max()
# Out:
# Marital Status
# Unmarried        259390.74
# Married          600445.61
# Divorced         215621.00
# Unarried          28454.01
# Widowed          103019.00
# Separated        100980.01
# Never-married    108447.10
# Name: Salary, dtype: float64

# %%
#5.sort age-wise salary
df.sort_values(['Salary','Age'])
# Out:
#          Workclass  Fnlwgt         Education  Experience Marital Status  \
# Age
# 53   Self Employed   76860           Masters           9        Married
# 47         Private   21906           Masters          14      Unmarried
# 20         Private  148294  Senior Secondary           0      Unmarried
# 22         Private  284317  Senior Secondary          12      Unmarried
# 25         Private   98155         Bachelors           2      Unmarried
# ..             ...     ...               ...         ...            ...
# 46    Self Empoyed  214627         Doctorate          16        Married
# 23      Government   28856         Bachelors           1        Married
# 50         Private  181901            Others          28        Married
# 51      Government  114508           Masters          15        Married
# 42         Private  118494         Doctorate          10        Married
#
#                Occupation     Sex  Hours per Week         Salary
# Age
# ...

# %%
#6 mean salary
print(df['Salary'].mean())
# Out:
# 63588.04698538986

# %%
df.set_index("Age",inplace=True)
df.sort_index(ascending=True)
# Out:
#          Workclass  Fnlwgt         Education  Experience Marital Status  \
# Age
# 18         Private  152004  Senior Secondary           0      Unmarried
# 18         Private  293227       High School           2      Unmarried
# 18         Private  177722       High School           9      Unmarried
# 19   Self Employed   52114         Bachelors          10      Unmarried
# 19   Self Employed  117201  Senior Secondary           3      Unmarried
# ..             ...     ...               ...         ...            ...
# 58         Private  178644         Bachelors           9        Widowed
# 59      Government  107287         Bachelors          18        Widowed
# 59         Private   81929         Doctorate          16        Widowed
# 60         Private  199085      High School           26        Married
# 68         Private  192052         Doctorate          10        Widowed
#
#          Occupation     Sex  Hours per Week    Salary
# Age
# ...

# %%
for i in range(23,51):
    print(df.loc[i])
# Out:
#       Workclass  Fnlwgt  Education  Experience Marital Status  \
# Age
# 23      Private  205865  Bachelors           1      Unmarried
# 23   Government   28856  Bachelors           1        Married
# 23      Private  543028  Bachelors           9      Unmarried
# 23      Private  257509  Bachelors           0      Unmarried
# 23      Private  375871  Bachelors           1        Married
# 23   Government  184699  Bachelors           9      Unmarried
# 23   Government  115244  Bachelors           0      Unmarried
# 23      Private  387641     Others           1      Unmarried
# 23      Private  120251  Bachelors           1      Unmarried
# 23      Private  198542  Bachelors           1      Unmarried
# 23      Private   44064    Masters          10      Separated
# 23      Private  227856  Bachelors           1      Unmarried
#
#                Occupation     Sex  Hours per Week     Salary
# Age
# 23      Executive Manager    Male              28   31577.01
# ...

# %%
#8.details for which workclass is private 
df[df['Workclass']=='Private']
# Out:
#     Workclass  Fnlwgt  Education  Experience Marital Status  \
# Age
# 23    Private  205865  Bachelors           1      Unmarried
# 48    Private  144397  Bachelors          10       Divorced
# 28    Private  164170     Others           4        Married
# 40    Private  170108    Masters          14        Married
# 47    Private  341995    Masters          10       Divorced
# ..        ...     ...        ...         ...            ...
# 46    Private  192963  Bachelors          13        Married
# 39    Private  143123    Masters          11        Married
# 39    Private  237713  Bachelors          15        Married
# 59    Private   81929  Doctorate          16        Widowed
# 46    Private  456062  Doctorate          16        Married
#
#                   Occupation     Sex  Hours per Week     Salary
# Age
# 23         Executive Manager    Male              28   31577.01
# 48        Technical  Support  Female              30   25541.66
# ...

# %%
#9. insights for age wise salary
df.groupby("Age")["Salary"].sum().plot()
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
#10 experince wise salary
df.groupby("Experience")["Salary"].sum().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Experience'>
